# %%
import pandas as pd
import numpy as np

# %%
preferences = pd.read_csv("/Users/paulina.kalinowska/Desktop/project/Hackathon-16.11.2019/data/csv/preferences.csv")

# %%
df
# Out:
#     Unnamed: 0                                         preference  \
# 0            1                                                age
# 1            2                                               city
# 2            3                                    likes monuments
# 3            4                                       likes hiking
# 4            5                                  likes restaurants
# 5            6                              interested in history
# 6            7                                likes long journeys
# 7            8                                           is brave
# 8            9                                      likes cycling
# 9           10                                     likes swimming
# 10          11                                       likes crowds
# 11          12                                      travels often
# 12          13                                    likes paintings
# 13          14                         likes going to the theatre
# 14          15                                 gets bored quickly
# 15          16                                         likes heat
# 16          17                                     likes concerts
# 17          18                  likes spending time in the nature
# 18          19                                   likes big cities
# 19          20                                  likes small towns
# 20          21               enjoys sleeping in high-class hotels
# 21          22                         enjoys sleeping in hostels
# 22          23                            speaks English fluently
# 23          24  looks for information about the cities on the ...
# 24          25                            uses the internet often
# 25          26               always has a cell phone with him/her
# 26          27                               usually takes a taxi
# 27          28                                      likes animals
# 28          29                                        likes parks
# 29          30                                      likes the sea
# 30          31               would like to show his/hers hometown
# 31          32                likes exploring non-touristy places
# 32          33                                    likes mountains
#
#    preferences_mom preferences_dad preferences_son preferences_daughter  \
# 0               40              38               9                    4
# 1           poznan          dublin   poznan/dublin        poznan/dublin
# 2                3               3               5                    1
# 3                5               2               5                    4
# 4                4               5               4                    4
# 5                4               4               5                    2
# 6                4               2               5                    4
# 7                4               2               5                    5
# 8                5               2               5                    4
# 9                5               3               5                    5
# 10               3               1               3                    5
# 11               4               5               4                    4
# 12               3               4               3                    5
# 13               3               4               2                    5
# 14               3               3               5                    5
# 15               3               2               3                    5
# 16               5               5               3                    4
# 17               5               3               4                    5
# 18               4               3               4                    5
# 19               3               3               3                    3
# 20               4               5               3                    3
# 21               4               3               4                    5
# 22               5               5               5                    5
# 23               5               5               5                    2
# 24               5               4               5                    4
# 25               5               4               5                    3
# 26               4               5               3                    3
# 27               3               4               5                    5
# 28               5               3               5                    5
# 29               3               3               5                    5
# 30               3             NaN             NaN                  NaN
# 31               5               4               2                    5
# 32               5               3               3                    4
#
#    preferences_grandma preferences_grandpa preferences_woofer_the_dog
# 0                   65                  68                          2
# 1              kumquat          goji_berry              poznan/dublin
# 2                    4                   5                          1
# 3                    2                   5                          5
# 4                    5                   3                          1
# 5                    4                   5                          1
# 6                    1                   4                          1
# 7                    3                   5                          5
# 8                    2                   5                          5
# 9                    1                   3                          5
# 10                   1                   3                          1
# 11                   3                   3                          5
# 12                   5                   2                          1
# 13                   5                   2                          1
# 14                   3                   5                          5
# 15                   1                   3                          1
# 16                   5                   3                          1
# 17                   3                   5                          5
# 18                   5                   3                          1
# 19                   3                   4                          5
# 20                   5                   3                          1
# 21                   1                   2                          5
# 22                   3                   2                          5
# 23                   1                   2                        NaN
# 24                   2                   3                        NaN
# 25                   2                   2                        NaN
# 26                   5                   3                          1
# 27                   3                   5                          5
# 28                   4                   5                          5
# 29                   5                   2                          5
# 30                   5                   4                        NaN
# 31                   3                   5                          5
# 32                   3                   5                          5
